# %%
# Importing the libraries 

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Ignore harmless warnings 

import warnings 
warnings.filterwarnings("ignore")

# %%
# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# %%
# Import psql to run queries 

import pandasql as psql

# %%
dataset= pd.read_csv(r"C:\Users\Admin\Downloads\files\13,14-08-22\MY2021_Fuel_Consumption_Ratings (1).csv" , header=0)

# %%
dataset_bk=dataset.copy()

# %%
dataset.head()
# Out:
#    Year   Make              Model Vehicle_Class  Engine_Size  Cylinders  \
# 0  2021  Acura                ILX       Compact          2.4          4
# 1  2021  Acura                NSX    Two-seater          3.5          6
# 2  2021  Acura         RDX SH-AWD    SUV: Small          2.0          4
# 3  2021  Acura  RDX SH-AWD A-SPEC    SUV: Small          2.0          4
# 4  2021  Acura         TLX SH-AWD       Compact          2.0          4
#
#   Transmission Fuel_Type  Fuel_Consumption_city  Fuel_Consumption_Hwy  \
# 0          AM8         Z                    9.9                   7.0
# 1          AM9         Z                   11.1                  10.8
# 2         AS10         Z                   11.0                   8.6
# 3         AS10         Z                   11.3                   9.1
# 4         AS10         Z                   11.2                   8.0
#
#    Fuel_Consumption_Comb  Fuel_Consumption_Comb_MPG  CO2_Emissions  \
# 0                    8.6                         33            199
# 1                   11.0                         26            256
# 2                    9.9                         29            232
# 3                   10.3                         27            242
# 4                    9.8                         29            230
#
#    CO2_Rating  Smog_Rating
# 0           6            3
# 1           4            3
# 2           5            6
# 3           5            6
# 4           5            7

# %%
dataset.tail(10)
# Out:
#      Year   Make          Model         Vehicle_Class  Engine_Size  Cylinders  \
# 873  2021  Volvo     S90 T6 AWD              Mid-size          2.0          4
# 874  2021  Volvo         V60 T5  Station wagon: Small          2.0          4
# 875  2021  Volvo     V60 T6 AWD  Station wagon: Small          2.0          4
# 876  2021  Volvo  V60 CC T5 AWD  Station wagon: Small          2.0          4
# 877  2021  Volvo    XC40 T4 AWD            SUV: Small          2.0          4
# 878  2021  Volvo    XC40 T5 AWD            SUV: Small          2.0          4
# 879  2021  Volvo    XC60 T5 AWD            SUV: Small          2.0          4
# 880  2021  Volvo    XC60 T6 AWD            SUV: Small          2.0          4
# 881  2021  Volvo    XC90 T5 AWD         SUV: Standard          2.0          4
# 882  2021  Volvo    XC90 T6 AWD         SUV: Standard          2.0          4
#
#     Transmission Fuel_Type  Fuel_Consumption_city  Fuel_Consumption_Hwy  \
# 873          AS8         Z                   11.3                   7.5
# 874          AS8         Z                   10.0                   6.8
# 875          AS8         Z                   11.3                   7.5
# 876          AS8         Z                   10.8                   7.7
# 877          AS8         X                   10.7                   7.6
# 878          AS8         Z                   10.7                   7.7
# 879          AS8         Z                   11.1                   8.3
# 880          AS8         Z                   11.7                   8.6
# 881          AS8         Z                   11.5                   8.4
# 882          AS8         Z                   12.1                   8.5
#
#      Fuel_Consumption_Comb  Fuel_Consumption_Comb_MPG  CO2_Emissions  \
# 873                    9.6                         29            224
# 874                    8.6                         33            200
# 875                    9.6                         29            224
# 876                    9.4                         30            220
# 877                    9.3                         30            217
# 878                    9.4                         30            219
# 879                    9.9                         29            230
# 880                   10.3                         27            240
# 881                   10.1                         28            236
# 882                   10.5                         27            245
#
#      CO2_Rating  Smog_Rating
# 873           5            7
# 874           6            5
# 875           5            7
# 876           5            5
# 877           5            5
# 878           5            5
# 879           5            5
# 880           5            7
# 881           5            5
# 882           5            7

# %%
dataset.sample(10)
# Out:
#      Year         Make                Model           Vehicle_Class  \
# 501  2021  Lamborghini    Aventador Coupe S              Two-seater
# 853  2021       Toyota            Venza AWD              SUV: Small
# 350  2021          GMC               Sierra  Pickup truck: Standard
# 563  2021        Mazda                 CX-5              SUV: Small
# 683  2021       Nissan                Kicks                Mid-size
# 805  2021       Toyota          4Runner 4WD           SUV: Standard
# 545  2021     Maserati             Ghibli S                Mid-size
# 797  2021       Subaru   Impreza 5-Door AWD    Station wagon: Small
# 483  2021          Kia               K5 AWD               Full-size
# 656  2021         MINI  Cooper Clubman ALL4                Mid-size
#
#      Engine_Size  Cylinders Transmission Fuel_Type  Fuel_Consumption_city  \
# 501          6.5         12          AM7         Z                   27.9
# 853          2.5          4           AV         X                    5.9
# 350          5.3          8           A8         X                   14.0
# 563          2.5          4          AS6         X                    9.7
# 683          1.6          4           AV         X                    7.7
# 805          4.0          6          AS5         X                   14.8
# 545          3.0          6          AS8         Z                   13.8
# 797          2.0          4           M5         X                   10.1
# 483          1.6          4          AS8         X                    9.2
# 656          1.5          3          AS8         Z                    9.7
#
#      Fuel_Consumption_Hwy  Fuel_Consumption_Comb  Fuel_Consumption_Comb_MPG  \
# 501                  15.7                   22.4                         13
# 853                   6.4                    6.1                         46
# 350                  10.1                   12.3                         23
# 563                   7.8                    8.8                         32
# 683                   6.6                    7.2                         39
# 805                  12.5                   13.8                         20
# 545                   9.5                   11.9                         24
# 797                   7.7                    9.0                         31
# 483                   6.9                    8.2                         34
# 656                   7.0                    8.5                         33
#
#      CO2_Emissions  CO2_Rating  Smog_Rating
# 501            520           1            1
# 853            141           8            7
# 350            288           3            5
# 563            206           6            7
# 683            169           7            7
# 805            321           3            5
# 545            277           4            3
# 797            211           5            6
# 483            193           6            5
# 656            198           6            7

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 15 columns):
# Year                         883 non-null int64
# Make                         883 non-null object
# Model                        883 non-null object
# Vehicle_Class                883 non-null object
# Engine_Size                  883 non-null float64
# Cylinders                    883 non-null int64
# Transmission                 883 non-null object
# Fuel_Type                    883 non-null object
# Fuel_Consumption_city        883 non-null float64
# Fuel_Consumption_Hwy         883 non-null float64
# Fuel_Consumption_Comb        883 non-null float64
# Fuel_Consumption_Comb_MPG    883 non-null int64
# CO2_Emissions                883 non-null int64
# CO2_Rating                   883 non-null int64
# Smog_Rating                  883 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 103.6+ KB

# %%
# Delecting the 8 columns

dataset = dataset.drop(['Year', 'Make', 'Model', 'Vehicle_Class', 'Transmission',
                                 'Fuel_Type', 'CO2_Rating', 'Smog_Rating'], axis = 1)
dataset.head()
# Out:
#    Engine_Size  Cylinders  Fuel_Consumption_city  Fuel_Consumption_Hwy  \
# 0          2.4          4                    9.9                   7.0
# 1          3.5          6                   11.1                  10.8
# 2          2.0          4                   11.0                   8.6
# 3          2.0          4                   11.3                   9.1
# 4          2.0          4                   11.2                   8.0
#
#    Fuel_Consumption_Comb  Fuel_Consumption_Comb_MPG  CO2_Emissions
# 0                    8.6                         33            199
# 1                   11.0                         26            256
# 2                    9.9                         29            232
# 3                   10.3                         27            242
# 4                    9.8                         29            230

# %%
# Identify the Independent and Target variables

IndepVar = []
for col in dataset.columns:
    if col != 'CO2_Emissions':
        IndepVar.append(col)

TargetVar = 'CO2_Emissions'

x =dataset [IndepVar]
y =dataset [TargetVar]

# %%
# Split the data into train and test sets

from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train = mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

x_test = mmscaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test)

# %%
#train the algorithm and build the model with train dataset

from sklearn.linear_model import LinearRegression

# Create model object

MulRGR = LinearRegression()

#LinearRegression(fit_intercept=True, normalize='deprecated', copy_X=True, n_jobs=None, positive=False)

# Train the model with training dataset (70%)

MulRGR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=MulRGR.predict(x_test)

# %%
# Evaluation metrics for Regression analysis

from sklearn import metrics

print('Mean Absolute Error (MAE):',  round(metrics.mean_absolute_error(y_test, y_pred),3))  
print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test,y_pred))),3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b8204d1eaf68> in <module>
#       4
#       5 print('Mean Absolute Error (MAE):',
# ----> 6       round(metrics.mean_absolute_error(y_test, y_pred),3))
#       7 print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))
#       8 print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
#
# NameError: name 'y_test' is not defined

# %%
# Define the function to calculate the MAPE - Mean Absolute Percentage Error

def MAPE (y_test, y_pred): 
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# Evaluation of MAPE 

result = MAPE(y_test, y_pred)
print('Mean Absolute Percentage Error (MAPE):', round(result, 3), '%')
#Sruthi G21:55
#print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test,y_pred))),3))
# Out:
# Mean Absolute Percentage Error (MAPE): 10.726 %

# %%
# Calculate Adjusted R squared values 

r_squared = round(metrics.r2_score(y_test, y_pred),6)
adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
print('Adj R Square: ', adjusted_r_squared)
# Out:
# Adj R Square:  0.583492

# %%
Results = pd.DataFrame({'CO2_Emissions_A':y_test, 'CO2_Emissions_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = dataset_bk.merge(Results, left_index=True, right_index=True)
ResultsFinal.sample(6)
# Out:
#      Year       Make                                        Model  \
# 158  2021  Chevrolet                                   Blazer AWD
# 473  2021       Jeep  Wrangler JL Unlimited 4X4 Rubicon EcoDiesel
# 148  2021   Cadillac                                          XT4
# 250  2021      Dodge                                  Charger AWD
# 212  2021  Chevrolet                                 Suburban 4WD
# 582  2021      Mazda                                         MX-5
#
#      Vehicle_Class  Engine_Size  Cylinders Transmission Fuel_Type  \
# 158     SUV: Small          2.0          4           A9         X
# 473     SUV: Small          3.0          6           A8         D
# 148     SUV: Small          2.0          4          AS9         Z
# 250      Full-size          3.6          6           A8         X
# 212  SUV: Standard          3.0          6          A10         D
# 582     Two-seater          2.0          4          AS6         Z
#
#      Fuel_Consumption_city  Fuel_Consumption_Hwy  Fuel_Consumption_Comb  \
# 158                   10.6                   8.7                    9.7
# 473                   11.2                   9.0                   10.2
# 148                    9.9                   7.8                    8.9
# 250                   12.8                   8.7                   11.0
# 212                   12.0                   8.9                   10.6
# 582                    9.0                   6.6                    7.9
#
#      Fuel_Consumption_Comb_MPG  CO2_Emissions  CO2_Rating  Smog_Rating  \
# 158                         29            227           5            7
# 473                         28            275           4            1
# 148                         32            209           5            7
# 250                         26            258           4            3
# 212                         27            277           4            3
# 582                         36            186           6            3
#
#      CO2_Emissions_A  CO2_Emissions_P
# 158              227       242.406642
# 473              275       266.568253
# 148              209       221.379879
# 250              258       292.480315
# 212              277       278.320353
# 582              186       196.526558
